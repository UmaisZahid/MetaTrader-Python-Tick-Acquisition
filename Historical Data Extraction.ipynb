# %%
# %run "dwx_tick_data_io".py
# %load_ext autoreload
# %autoreload
# %matplotlib notebook
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
htdExtractor = DWX_TICK_DATA_IO(_path=r'C:\Users\zahid\OneDrive\Historical Tick Data\Historical Tick Data Original')

output = htdExtractor._get_symbol_as_dataframe_(_symbol='GBPUSD', _precision='tick', _date='2019-05-27',_hour='12')
# Out:
# [INFO] Finding symbol files.. please wait..
# [INFO] Processing BID (1) / ASK (1) files.. please wait..
# BIDS: 1 / 1 - C:\Users\zahid\OneDrive\Historical Tick Data\Historical Tick Data Original/GBPUSD/GBPUSD_BID_2019-05-27_12.log.gz
# ASKS: 1 / 1 - C:\Users\zahid\OneDrive\Historical Tick Data\Historical Tick Data Original/GBPUSD/GBPUSD_ASK_2019-05-27_12.log.gz

# %%
output
# Out:
#                          ask_price  bid_price
# timestamp
# 2019-05-27 12:00:01.753    1.26928    1.26921
# 2019-05-27 12:00:01.809    1.26928    1.26922
# 2019-05-27 12:00:01.854    1.26928    1.26921
# 2019-05-27 12:00:04.115    1.26928    1.26922
# 2019-05-27 12:00:04.425    1.26928    1.26921
# 2019-05-27 12:00:04.523    1.26926    1.26921
# 2019-05-27 12:00:04.551    1.26926    1.26920
# 2019-05-27 12:00:04.575    1.26925    1.26920
# 2019-05-27 12:00:04.626    1.26925    1.26918
# 2019-05-27 12:00:04.645    1.26926    1.26918
# 2019-05-27 12:00:04.646    1.26926    1.26919
# 2019-05-27 12:00:04.702    1.26925    1.26919
# 2019-05-27 12:00:07.099    1.26925    1.26918
# 2019-05-27 12:00:08.783    1.26925    1.26917
# 2019-05-27 12:00:08.829    1.26924    1.26917
# 2019-05-27 12:00:09.372    1.26924    1.26918
# 2019-05-27 12:00:09.918    1.26924    1.26917
# 2019-05-27 12:00:11.883    1.26924    1.26918
# 2019-05-27 12:00:11.896    1.26924    1.26917
# ...
